# %%
print('Program starts')

age=10

if age >= 18:
    print("You are an adult")
    print("You can vote")

print('program ends')
# Out:
# Program starts
# program ends

# %%
print('Program starts')

age=20

if age >= 18:
    print("You are an adult")
    print("You can vote")

print('program ends')
# Out:
# Program starts
# You are an adult
# You can vote
# program ends

# %%
print('Program starts')

age=10

if age >= 18:
    print("You are an adult")
    print("You can vote")
else:
    print("You are a minor")

print('program ends')
# Out:
# Program starts
# You are a minor
# program ends

# %%
temp=20
if (temp>=25):
    print("Turning on teh AC")
else:
    print("Turning on the heater")
# Out:
# Turning on the heater

# %%
total=11000

if total>=10000:
    print("You get a 10% discount")
elif total>=5000:
    print("You get a 5% discount")
elif total>=1000:
    print("You get a 3% discount")
else:
    print("No discount for you")
# Out:
# You get a 10% discount

# %%
#logical operators
# and, or, not


married=True

if not married:
    print("You are married")
else:
    print("You are not married")
# Out:
# You are not married

# %%
password='1234'

if not (password=='1234'):
    print("Password is correct")
else:
    print("Password is incorrect")
# Out:
# Password is incorrect

# %%
temp=20
humidity=80

if temp>=25 and humidity>=70:
    print("Turning on the AC")
else:
    print("Turning on the heater")
# Out:
# Turning on the heater

# %%
temp=10
humidity=10

if  False or False:
    print("Turning on the AC")
else:
    print("Turning on the heater")
# Out:
# Turning on the heater

# %%
total=8000

if total>=5000 and total<=10000:
    print("Total is within the range")
# Out:
# Total is within the range

# %%
username="admin"
password="1234"

if username=="admin":
    if password=="1234":
        print("Login successful")
    else:
        print("Incorrect password")
else:
    print("Invalid username")
# Out:
# Login successful

# %%
if total>10000:
    print("You get a 10% discount")
elif total>5000:
    pass
else:
    print("You get no discount")
