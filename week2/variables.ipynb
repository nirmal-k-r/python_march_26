# %%
name = "Paul" #valid variable name
2name = "Paul" #invalid variable name, starts with a number
Name="Paul" #valid variable name but not recommended, variable names should be lowercase
naMe="Paul" 
first name="Paul" #invalid variable name, contains a space
first_name="Paul" #valid variable name, uses an underscore to separate words
firstName="Paul" #valid variable name, uses camelCase to separate words
first@name="Paul" #invalid variable name, contains a special character, only underscores are allowed
_name="Paul" #valid variable name, starts with an underscore, but not recommended as it is often used for private variables in classes
name2="Paul" #valid variable name
name2first="Paul"

# %%
#constants
PI=3.1456
GRAVITY=9.81

# %%
age = 25
print(age)
print('age')
# Out:
# 25
# age

# %%
print("Age: ",age)
# Out:
# Age:  25

# %%
print( type(age) )
# Out:
# <class 'int'>

# %%
name="Tom"
print(name)
print(type(name))
# Out:
# Tom
# <class 'str'>

# %%
total=100.50
print(total)
print(type(total))
# Out:
# 100.5

# %%
price=100.0
print(price)
print(type(price))
# Out:
# 100.0
# <class 'float'>

# %%
#comment

# this is a comment

print("Hello World") # this is a comment after code

#print('im eating')
# Out:
# Hello World

# %%
#strings
name="A"
name='a'
name="Paul"
setence="This is a sentence."
para="""This is a paragraph 5678.
this is a long paragraph.
@$%^&*()_(*&^%$)
"""


print(para)


id="10000001"
print(id)
print(type(id))
# Out:
# This is a paragraph 5678.
# this is a long paragraph.
# @$%^&*()_(*&^%$)
#
# 10000001
# <class 'str'>

# %%
married=True
print(married)

adult=False
print(adult)
# Out:
# True
# False
