# %%
name="Nirmal"
age=10
price=1000.201
married=True

# %%
print("This is a sentence")
print(f"My name is {name} and I am {age} years old.")


print("My name is" + name + " and i am "+ int(age) + "years old.")
# Out:
# This is a sentence
# My name is Tom and I am 10 years old.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       1 print("This is a sentence")
#       2 print(f"My name is {name} and I am {age} years old.")
# ----> 5 print("My name is" + name + " and i am "+ age+ "years old.")
#
# TypeError: can only concatenate str (not "int") to str

# %%
name=input("What is your name? ")
print(f"Hello {name}!")
# Out:
# Hello Tom!

# %%
x=10
y=50

z=x+y
print(z)
# Out:
# 60

# %%
balance=6000

withdrawal_amount=input("How much do you want to withdraw? ")
withdrawal_amount=int(withdrawal_amount) 

if withdrawal_amount<=balance:
    balance=balance-withdrawal_amount
    print(f"Your withdrawal of {withdrawal_amount} was successful. Your new balance is {balance}.")
else:
    print("Insufficient funds. Withdrawal failed.")

# %%
temp=30

if temp>25:
    print('Turn on ac for 5 minutes')
    x=19

else:
    print('Open the windows for 5 minutes')

print(x)
# Out:
# Turn on ac for 5 minutes
# 19

# %%
total=10000
if (total>10000):
    print("You are eligible for a 10% discount and yoy get a gift")
elif (total>5000):
    print("You are eligible for a 5% discount")
else:
    print("You are not eligible for any discount")
