# %%
#function definition

def sayHello():
    print("Hello there")
    print("Welcome to the world of Python")

# %%
#function call
sayHello()
# Out:
# Hello there
# Welcome to the world of Python

# %%
sayHello()
sayHello()
sayHello()
# Out:
# Hello there
# Welcome to the world of Python
# Hello there
# Welcome to the world of Python
# Hello there
# Welcome to the world of Python

# %%
print('Program starts')

sayHello()

print('Program ends')

sayHello()
# Out:
# Program starts
# Hello there
# Welcome to the world of Python
# Program ends
# Hello there
# Welcome to the world of Python

# %%
for i in range(5):
    sayHello()
# Out:
# Hello there
# Welcome to the world of Python
# Hello there
# Welcome to the world of Python
# Hello there
# Welcome to the world of Python
# Hello there
# Welcome to the world of Python
# Hello there
# Welcome to the world of Python

# %%
def avg(a,b):
    sum=a+b
    result=sum/2
    print(result)



#main program
avg(5,10)
avg(100,200)
avg(1.5,2.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 10
#       8 #main program
#       9 avg(5,10)
# ---> 10 print(result)
#      11 avg(100,200)
#      12 avg(1.5,2.5)
#
# NameError: name 'result' is not defined

# %%
def avg(a,b):
    sum=a+b
    result=sum/2
    return result



#main program
print(avg(100,200))

result=avg(5,10)
print(result)
# Out:
# 150.0
# 7.5

# %%
def process():
    pass #placeholder for future code


print('Program starts')
# Out:
# Program starts

# %%
def calculate_area(length,width):
    area=length*width
    return area


l=5
w=10
# area=calculate_area(5,10)
area=calculate_area(l,w)
print('Area of rectangle:',area)
# Out:
# Area of rectangle: 50

# %%
def register(nic, name, address, gender, married):
    print(f'NIC: {nic} Name: {name} Address: {address} Gender: {gender} Married: {married}')


register('123456789V', 'John Doe', '123 Main St', 'Male', False)
register('987654321V', 'Jane Smith', '456 Elm St', 'Female', False)
register('555555555V', 'Alice Johnson', '789 Oak St', 'Female',False)
register('111111111V', 'Bob Brown', '321 Pine St', 'Male',False)
register('222222222V', 'Charlie Davis', '654 Maple St', 'Male',True)
register('333333333V', 'Eve Wilson', '987 Cedar St', 'Female',False)
# Out:
# NIC: 123456789V Name: John Doe Address: 123 Main St Gender: Male Married: False
# NIC: 987654321V Name: Jane Smith Address: 456 Elm St Gender: Female Married: False
# NIC: 555555555V Name: Alice Johnson Address: 789 Oak St Gender: Female Married: False
# NIC: 111111111V Name: Bob Brown Address: 321 Pine St Gender: Male Married: False
# NIC: 222222222V Name: Charlie Davis Address: 654 Maple St Gender: Male Married: True
# NIC: 333333333V Name: Eve Wilson Address: 987 Cedar St Gender: Female Married: False

# %%
def register(nic, name,address, gender, married=False):
    print(f'NIC: {nic} Name: {name} Address: {address} Gender: {gender} Married: {married}')


register('123456789V', 'John Doe', '123 Main St', 'Male')
register('987654321V', 'Jane Smith', '456 Elm St', 'Female')
register('555555555V', 'Alice Johnson', '789 Oak St', 'Female')
register('111111111V', 'Bob Brown', '321 Pine St', 'Male')
register('222222222V', 'Charlie Davis', '654 Maple St', 'Male',True)
register('333333333V', 'Eve Wilson', '987 Cedar St', 'Female')
# Out:
# NIC: 123456789V Name: John Doe Address: 123 Main St Gender: Male Married: False
# NIC: 987654321V Name: Jane Smith Address: 456 Elm St Gender: Female Married: False
# NIC: 555555555V Name: Alice Johnson Address: 789 Oak St Gender: Female Married: False
# NIC: 111111111V Name: Bob Brown Address: 321 Pine St Gender: Male Married: False
# NIC: 222222222V Name: Charlie Davis Address: 654 Maple St Gender: Male Married: True
# NIC: 333333333V Name: Eve Wilson Address: 987 Cedar St Gender: Female Married: False

# %%
def avg(a,b,c):
    sum=a+b+c
    result=sum/3
    return result

def avg(a,b,c,d):
    sum=a+b+c+d
    result=sum/4
    return result

def avg(a,b,c,d,e):
    sum=a+b+c+d+e
    result=sum/5
    return result

# %%
def avg(*numbers): #variable length arguments

    total=0
    for num in numbers:
        total=total+num
    result=total/len(numbers)
    
    print('Average:',result)


avg(1)
avg(1,2,3,4,5)
avg(1,2,3)
# Out:
# Average: 1.0
# Average: 3.0
# Average: 2.0

# %%
def filter(**params): #variable keyword arguments
    print(params)

filter(rating=4, region="North", maxPrice=12000)
